# %%
import pandas as pd
file = "/Users/yathisha/Desktop/untitled folder 2/un-general-debates-blueprint.csv"
df = pd.read_csv(file)
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# 15       25  1970     DZA                          Algeria
# 16       25  1970     ECU                          Ecuador
# 17       25  1970     FRA                           France
# 18       25  1970     GBR                   United Kingdom
# 19       25  1970     GHA                            Ghana
#
#                   speaker    position  \
# 0                 Mr. NAS         NaN
# 1      Mr. DE PABLO PARDO         NaN
# 2             Mr. McMAHON         NaN
# 3      Mr. KIRCHSCHLAEGER         NaN
# 4              Mr. HARMEL         NaN
# 5          Mr. GURINOVICH         NaN
# 6      Mr. CAMACHO OMISTE         NaN
# 7      Mr. GIBSON BARBOZA         NaN
# 8               Mr. SHARP         NaN
# 9              Mr. AHIDJO  President
# 10            Mr. ICKONGA         NaN
# 11  Mr. VASQUEZ CARRIZOSA         NaN
# 12              Mr. FACIO         NaN
# 13            Mr. ALARCON         NaN
# 14        Mr FERNANDEZ G.
# 15              Mr. YAZID         NaN
# 16            Mr. Benites         NaN
# 17           Mr. SCHUMANN         NaN
# 18   Sir Alec DOUGLASHOME         NaN
# 19              Mr. OWUSU         NaN
#
#                                                  text
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   \n71.\t. We are today mourning the untimely de...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   \nThe General Assembly is fortunate indeed to ...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  \n\n\n Mr. President, it was a source of great...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...

# %%
df = df.sample(frac=0.2)

# %%
df.columns
df.dtypes
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1501 entries, 1253 to 5360
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       1501 non-null   int64
#  1   year          1501 non-null   int64
#  2   country       1501 non-null   object
#  3   country_name  1501 non-null   object
#  4   speaker       1497 non-null   object
#  5   position      922 non-null    object
#  6   text          1501 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 93.8+ KB
#            session         year
# count  1501.000000  1501.000000
# mean     49.970686  1994.970686
# std      12.912648    12.912648
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %%
df['length'] = df['text'].str.len()
df.describe()
# Out:
#            session         year        length
# count  1501.000000  1501.000000   1501.000000
# mean     49.970686  1994.970686  17644.740839
# std      12.912648    12.912648   7556.854292
# min      25.000000  1970.000000   3377.000000
# 25%      39.000000  1984.000000  11965.000000
# 50%      51.000000  1996.000000  16155.000000
# 75%      61.000000  2006.000000  21971.000000
# max      70.000000  2015.000000  63259.000000

# %%
df.describe(include='O')
# Out:
#        country country_name                  speaker  \
# count     1501         1501                     1497
# unique     197          197                     1367
# top        CAN       Canada  Michelle Bachelet Jeria
# freq        17           17                        4
#
#                             position  \
# count                            922
# unique                            39
# top     Minister for Foreign Affairs
# freq                             380
#
#                                                      text
# count                                                1501
# unique                                               1501
# top     ﻿I should like first of all, Sir, to congratul...
# freq                                                    1

# %%
df.isna().sum()
# Out:
# session           0
# year              0
# country           0
# country_name      0
# speaker           4
# position        579
# text              0
# length            0
# dtype: int64

# %%
df['speaker'].fillna('unknown', inplace=True)
df['position'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %%
df['speaker'] = df['speaker'].str.upper()
df['position'] = df['position'].str.upper()
df['text'] = df['text'].str.upper()

# %%
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name             speaker   position  \
# 6143       63  2008     USA  United States      GEORGE W. BUSH  PRESIDENT
# 2876       45  1990     USA  United States         GEORGE BUSH    UNKNOWN
# 5002       57  2002     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 3207       47  1992     USA  United States     MR. GEORGE BUSH  PRESIDENT
# 2720       44  1989     USA  United States                BUSH  PRESIDENT
# 5191       58  2003     USA  United States      GEORGE W. BUSH  PRESIDENT
#
#                                                    text  length
# 6143  I AM PLEASED TO BE HERE TO \nADDRESS THE GENER...   18384
# 2876  ﻿\nIT IS REALLY A GREAT PRIVILEGE TO GREET YOU...   15843
# 5002  ﻿WE MEET ONE YEAR AND ONE DAY\nAFTER A TERRORI...   16684
# 3207  FORTY-SEVEN YEARS AGO I WAS A YOUNG MAN OF 21,...   21105
# 2720  ﻿I AM HONOURED TO ADDRESS THE GENERAL ASSEMBLY...   19779
# 5191  ﻿TWENTY-FOUR MONTHS AGO, AND\nYESTERDAY IN THE...   16962

# %%
df['length'].plot()
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
g.fig.set_size_inches(10, 8) ###
# Out:
# /Users/yathisha/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import regex as re

# %%
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %%
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %%
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'hasn', 'he', 'ourselves', 'after', "couldn't", 'out', 'there', 'then', 'into', "needn't", 'won', 'on', 'this', 'through', 'how', 're', 'll', 'doesn', 'has', 'you', 'which', 'a', 'more', 'what', 'were', 'above', 'can', 'our', 'will', 'ma', "it's", 'or', 'under', 'am', 'over', 'again', 'm', 'such', 'couldn', "didn't", 'where', 'isn', 'when', 'having', 'the', 'should', 'before', 'not', 'she', 'against', 'own', 'it', 'was', 'have', 'both', 'an', "weren't", 'while', 'whom', 'wasn', 'are', 'mightn', "won't", 'themselves', 'until', 'at', "shan't", 'in', 'by', 'hers', 'nor', 'her', 'me', 'your', 'below', 'if', 'had', 'now', 'very', 'hadn', "wouldn't", 'from', 'than', 'once', 'do', 'being', 'to', 'here', 'itself', 'yours', "you've", "isn't", 't', 'their', "wasn't", 'ain', 'between', 'theirs', 'all', 'shouldn', 'my', 'why', 'and', 'no', "aren't", 'each', 'same', 'yourselves', 'his', 'about', "mightn't", 'off', "you're", "that'll", 'because', 'himself', 'him', "hasn't", 'yourself', 'those', "mustn't", 'during', 'is', 'been', 'for', 'aren', 'other', 'didn', "you'd", "she's", 'only', 'who', 's', 'with', 'these', "should've", 'so', 've', "doesn't", 'just', 'them', 'they', 'most', 'of', 'as', 'any', 'don', "shouldn't", 'down', "don't", "haven't", 'we', 'some', 'be', 'haven', 'shan', 'y', 'up', 'weren', 'i', 'its', "you'll", 'myself', 'doing', 'that', 'few', 'o', 'further', 'ours', 'herself', "hadn't", 'did', 'too', 'mustn', 'does', 'but', 'wouldn', 'needn', 'd'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yathisha/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
#Just testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %%
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
        return tokens

# %%
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country          country_name             speaker  \
# 6098       63  2008     PAN                Panama     MARTIN TORRIJOS
# 1290       35  1980     ETH              Ethiopia       GEDLE-GIORGIS
# 2336       42  1987     IND                 India              SINGH
# 6071       63  2008     MDA  Moldova, Republic of      ANDREI STRATAN
# 5360       59  2004     SUR              Suriname   MRS. MARIA LEVENS
#
#                           position  \
# 6098                     PRESIDENT
# 1290                       UNKNOWN
# 2336                       UNKNOWN
# 6071         DEPUTY PRIME MINISTER
# 5360  MINISTER FOR FOREIGN AFFAIRS
#
#                                                    text  length  \
# 6098  MY FIRST \nWORDS ARE ADDRESSED TO THE PRESIDEN...   10446
# 1290  ﻿I SHOULD LIKE, ON BEHALF OF THE ETHIOPIAN DEL...   24580
# 2336  ﻿MR. PRESIDENT, YOUR ELECTION TO THE PRESIDENC...   19471
# 6071  AT THE \nOUTSET, I WOULD LIKE TO CONGRATULATE ...    9082
# 5360  ON BEHALF OF THE\nGOVERNMENT AND PEOPLE OF THE...   10040
#
#                                                  tokens  num_tokens
# 6098  my first \nwords are addressed to the presiden...       10446
# 1290  ﻿i should like, on behalf of the ethiopian del...       24580
# 2336  ﻿mr. president, your election to the presidenc...       19471
# 6071  at the \noutset, i would like to congratulate ...        9082
# 5360  on behalf of the\ngovernment and people of the...       10040

# %%
from collections import Counter

# %%
tokens = tokenize("She likes my cats and my cats like my sofa.")
testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %%
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %%
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [(' ', 4035098), ('e', 2720705), ('t', 2153283), ('n', 1748684), ('i', 1744590)]

# %%
freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %%
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#           freq
# token
#        4035098
# e      2720705
# t      2153283
# n      1748684
# i      1744590
# o      1737859
# a      1716937
# s      1333187
# r      1324063
# h       940636

# %%
freq_df.describe()
# Out:
#                freq
# count  1.610000e+02
# mean   1.645016e+05
# std    5.247990e+05
# min    1.000000e+00
# 25%    3.000000e+00
# 50%    1.800000e+01
# 75%    7.639000e+03
# max    4.035098e+06

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/ac/66/937d1d73389c0b501c928c4d8513653063d2b40272dff70d0e283d8b9144/wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /Users/yathisha/anaconda3/lib/python3.11/site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in /Users/yathisha/anaconda3/lib/python3.11/site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/yathisha/anaconda3/lib/python3.11/site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yathisha/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/yathisha/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yathisha/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/yathisha/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/yathisha/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/yathisha/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yathisha/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/yathisha/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 1.7 MB/s eta 0:00:00a 0:00:01m
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# %%
text = df.query("year==1987 and country=='IND'")['text'].values[0]
plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
conditions = (df['year'] == 1987) & (df['country'] == 'IND')

if df[conditions].empty:
    print("No data found for the given conditions.")
else:
    
    text = df[conditions]['text'].values[0]

    
    wc = WordCloud(background_color='white', width=300, height=300, max_words=100, margin=2)
    wc.generate_from_text(text)

    
    plt.figure(figsize=(8, 8), facecolor=None)
    plt.imshow(wc)
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()

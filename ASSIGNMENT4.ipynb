# %% [markdown]
# # Introduction to Pandas

# %%
import pandas as pd

# %% [markdown]
# # Reading CSV File into a Pandas DataFrame

# %%
# Reading CSV file into a DataFrame
df=pd.read_csv("/Users/yathisha/Downloads/AmazonReviews.csv")
# Displaying a random sample of 20 rows from the DataFrame
df.sample(20)
# Out:
#             Id   ProductId          UserId  \
# 244174  244175  B0018CIUBA   AGPDKQIFYQ1YK
# 99173    99174  B000UXW95G   AFA92I5WLZ1AG
# 391640  391641  B006G7WC1G  A3L6YSYB1ITURN
# 53638    53639  B0016687F2   ACQLJJ7MVNVMH
# 311722  311723  B000EVG8H4  A1S0QN1U07RPIO
# 124748  124749  B0045X7H9A  A3V1A3C9DTLPME
# 316644  316645  B004FEN3GK   A8WRN6S6XGAG9
# 564689  564690  B00017LF24  A13FTUPT8BPSDL
# 246512  246513  B002D4DY8G  A2RX62V4E2BF5Z
# 540323  540324  B000C5YWZW  A2EDB3JN5NR01A
# 163396  163397  B005XB3U26  A2MIJQBZ78ZK9U
# 538705  538706  B000Q5X8DK  A24YOND7EZTD71
# 499897  499898  B009B87SAC   A966L65JSN8XN
# 271124  271125  B007FRD3HI  A1L5LTYCIEQIY4
# 111262  111263  B0030G1JJM  A1IQOJ2QUVVRAL
# 428500  428501  B002Y2OWII   A37XFZ7RN47R1
# 304240  304241  B001AS1A4Q  A1OAT06SZZF8E2
# 74734    74735  B0026RQTGE  A33HGS0F6NVBRA
# 261529  261530  B000MGWEZQ  A1GDHO0PV31SMB
# 315831  315832  B002ANCDRI  A1VZNYJIK4YWSK
#
#                                              ProfileName  \
# 244174                             Quick Vic "Quick Vic"
# 99173                      E. Yberg "Ed in Halesite, NY"
# 391640                                            JDrive
# 53638                                           Vegidude
# 311722                                        Rad Reader
# 124748                                       Peter Faden
# 316644            Brockeim "Playful Literary Adventurer"
# 564689                                          linda947
# 246512    Celeste "Vodka, Apple Pucker & Sweet 'n' Sour"
# 540323                                        Brandon R.
# 163396                                 Katherine A. Watt
# 538705                             Lehrerin "Trubertiam"
# 499897                            N. Schleif "night owl"
# 271124                                           R. Rowe
# 111262                      Lucretia Vandemark "Critter"
# 428500                                             nshja
# 304240                                 Castello "Rojo_P"
# 74734                                          C. Kinerd
# 261529                                          K. Harms
# 315831  Tuesday "Is it just me... or did S/E maybe do...
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 244174                     0                       2      3  1326931200
# 99173                      0                       0      5  1284940800
# 391640                     0                       0      5  1347235200
# 53638                      0                       0      4  1306022400
# 311722                     5                       5      5  1267228800
# 124748                     3                       4      4  1311292800
# 316644                     0                       0      5  1300838400
# 564689                     0                       0      5  1346544000
# 246512                     2                       2      5  1260662400
# 540323                    10                      10      1  1320969600
# 163396                     0                       0      5  1344297600
# 538705                     0                       0      5  1212105600
# 499897                     0                       0      5  1323820800
# 271124                     0                       0      5  1351036800
# 111262                     0                       0      5  1294876800
# 428500                     0                       0      5  1314835200
# 304240                     0                       0      5  1342396800
# 74734                     23                      23      5  1232409600
# 261529                     2                       2      5  1273104000
# 315831                     0                       0      5  1310601600
#
#                                                   Summary  \
# 244174                                      Dog loves 'em
# 99173                         delicious and convenient...
# 391640                                           Ja, mon!
# 53638                        Lean Body Shake - Strawberry
# 311722                               Too Yummy to be GF!!
# 124748                 Works well and tasted pretty good.
# 316644        The Same Crackers Found in Campfire S'Mores
# 564689               Diamond Crystal Popcorn and Nut Salt
# 246512                                              Tasty
# 540323  Vanilla beans from Halaleveryday were dry and ...
# 163396                         Bold coffee drinkers alert
# 538705                       Yummy, Healthy Anytime Snack
# 499897                     Only food my cats can agree on
# 271124                                 Perfect Early Grey
# 111262                                   Great Bread Mix!
# 428500                                   community coffee
# 304240                                  Converted Skeptic
# 74734                          Greenies - Catnip for dogs
# 261529  GREAT FOR ANTI-INFLAMMATORY DIETS AND FOR DIAB...
# 315831  My cat loves this, and even I think it smells ...
#
#                                                      Text
# 244174  Got these but they shorted me on the number th...
# 99173   not only are these noodles delicious, they fit...
# 391640  Big fat beans roasted just right....easy to ge...
# 53638   Great tasting product with very good mixabilit...
# 311722  We have tried many GF breads ... both prepared...
# 124748  I bought these after reading some of the other...
# 316644  Lingering evenings by campfires, sitting on ol...
# 564689  I love this salt! It is absolutely excellent o...
# 246512  I wish Gevalia came with an option for whole b...
# 540323  I purchased 6 vanilla beans from Halaleveryday...
# 163396  If you like a dark bold flavor this is the one...
# 538705  I like to keep snacks on hand, but not the cla...
# 499897  This is the only flavor of Science Diet (or an...
# 271124  I got a large container of this loose tea and ...
# 111262  I have used JB Bread Mix for a couple years. I...
# 428500  the best coffee in the world! Very good and de...
# 304240  I initially tried this product just to see wha...
# 74734   I have been using Greenies for years, includin...
# 261529  I HAVE RHEUMATOID ARTHRITIS AND AM ON A STRICT...
# 315831  I've bought several flavors of the b.f.f. line...

# %%
#!pip install scikit-learn

# %% [markdown]
# # Importing Modules from scikit-learn and NLTK

# %%
# Importing the preprocessing module from the scikit-learn library
from sklearn import preprocessing
# Importing the Natural Language Toolkit (NLTK)
import nltk
# Downloading the opinion lexicon dataset from NLTK
nltk.download('opinion_lexicon')
# Importing the opinion_lexicon dataset from the NLTK corpus module
from nltk.corpus import opinion_lexicon
# Importing the word_tokenize function from the NLTK tokenize module
from nltk.tokenize import word_tokenize
# Printing the total number of words in the opinion_lexicon dataset
print('Total number of words in opinion lexicon', len(opinion_lexicon.words()))
# Printing examples of positive words in the opinion_lexicon dataset
print('Examples of positive words in opinion lexicon',
      opinion_lexicon.positive()[:10])
# Printing examples of negative words in the opinion_lexicon dataset
print('Examples of negative words in opinion lexicon',
      opinion_lexicon.negative()[:10])
# Out:
# Total number of words in opinion lexicon 6789
# Examples of positive words in opinion lexicon ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation']
# Examples of negative words in opinion lexicon ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted']
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     /Users/yathisha/nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!

# %% [markdown]
# # Assigning Positive and Negative Scores

# %%
# Let's create a dictionary which we can use for scoring our review text

# Downloading punkt from NLTK library
nltk.download('punkt')

# Renaming the column 'reviewText' to 'Modules' in the DataFrame
df.rename(columns={"reviewText": "Modules"}, inplace=True)

# Assigning positive and negative scores
pos_score = 1
neg_score = -1

# Initializing an empty dictionary
word_dict = {}
 
# Adding the positive words to the dictionary
for word in opinion_lexicon.positive():
        word_dict[word] = pos_score
      
# Adding the negative words to the dictionary
for word in opinion_lexicon.negative():
        word_dict[word] = neg_score
# Out:
# [nltk_data] Downloading package punkt to /Users/yathisha/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Initializing Sentiment Score

# %%
#Creating a fuunction text
def bing_liu_score(Modules):
    #Initializing the sentiment score
    sentiment_score = 0
    #Tokenizing the input text into words and convert them to lowercase
    bag_of_words = word_tokenize(Modules.lower())
     # creating loop to check each word in the bag of words
    for word in bag_of_words:
        #Checking if the word exists in the sentiment dictionary
        if word in word_dict:
            # If the word exist, adding its sentiment score to the sentiment score
            sentiment_score += word_dict[word]
    return sentiment_score  #Returning the sentiment score for the text

# %% [markdown]
# # Handling Missing Values in the DataFrame

# %%
# Fill NaN values in the 'Summary' column
df['Summary'].fillna('no review', inplace=True)
#creating new column 'Bing_Liu_Score' to store the scores by applying  bing_liu_score to calculate sentiment scores for Review column
df['Bing_Liu_Score'] = df['Summary'].apply(bing_liu_score)

# %% [markdown]
# # Showing the First 5 Rows with Specific Columns

# %%
# Displaying the first 5 rows of the DataFrame with few columns
df[['Summary',"Id","Summary", 'Bing_Liu_Score']].head(5)
# Out:
#                  Summary  Id                Summary  Bing_Liu_Score
# 0  Good Quality Dog Food   1  Good Quality Dog Food               1
# 1      Not as Advertised   2      Not as Advertised               0
# 2  "Delight" says it all   3  "Delight" says it all               1
# 3         Cough Medicine   4         Cough Medicine               0
# 4            Great taffy   5            Great taffy               1

# %% [markdown]
# # Calculating Mean Sentiment Score

# %%
# Grouping the DataFrame by the 'Overall_Rating' column and calculating the mean of 'Bing_Liu_Score' for each group
df.groupby('Summary').agg({'Bing_Liu_Score':'mean'})
# Out:
#                                                     Bing_Liu_Score
# Summary
# ! It's HOT !                                                   1.0
# ! Mmmmmmmmmm !                                                 0.0
# ! WARNING !  Not for those who can't handle the...            -1.0
# !! NASTY !!                                                   -1.0
# !!!                                                            0.0
# ...                                                            ...
# ~~~TRIO OF ALL TIME FAVORITES~~~                               0.0
# «:::D:::» «:::E:::» «:::L:::» «:::I:::» «:::C::...             0.0
# «:::G:::» «:::R:::» «:::E:::» «:::A:::» «:::T::...             1.0
# ½ pounds, not 1.5                                              0.0
# Åwesome Coffee!!!                                              0.0
#
# [295743 rows x 1 columns]

# %% [markdown]
# # Calculating Mean Sentiment Score for Each Group based on ID

# %%
# Grouping the DataFrame by the 'Overall_Rating' column and calculating the mean of 'Bing_Liu_Score' for each group
df.groupby('Id').agg({'Bing_Liu_Score':'mean'})
# Out:
#         Bing_Liu_Score
# Id
# 1                  1.0
# 2                  0.0
# 3                  1.0
# 4                  0.0
# 5                  1.0
# ...                ...
# 568450             0.0
# 568451            -1.0
# 568452             1.0
# 568453             2.0
# 568454             1.0
#
# [568454 rows x 1 columns]
